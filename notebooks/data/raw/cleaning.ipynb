# %%
# %load_ext rmagic

# %%
# %%R
# #Infection Rate Per 100000 of Hiv Diagnosis, Adults and Adolescents
#
# HIV_Diagnoses = read.csv('HIV_Diagnoses.csv', header = F)
# clean.HIV_Diagnoses = (HIV_Diagnoses[4:60,1:2])
# print(clean.HIV_Diagnoses)
# Out:
#                          V1    V2
# 4                  Location Total
# 5             United States  19.0
# 6                   Alabama  20.9
# 7                    Alaska   4.6
# 8                   Arizona  13.3
# 9                  Arkansas  10.0
# 10               California  19.2
# 11                 Colorado   9.6
# 12              Connecticut  14.2
# 13                 Delaware  16.7
# 14     District of Columbia 177.9
# 15                  Florida  33.2
# 16                  Georgia  31.4
# 17                   Hawaii   6.8
# 18                    Idaho   3.0
# 19                 Illinois  20.0
# 20                  Indiana   9.5
# 21                     Iowa   5.0
# 22                   Kansas   6.2
# 23                 Kentucky   9.4
# 24                Louisiana  36.6
# 25                    Maine   5.2
# 26                 Maryland  36.4
# 27            Massachusetts  22.5
# 28                 Michigan   9.6
# 29                Minnesota   7.2
# ...

# %%
# %%R
# ##Citizenship Status
#
# Citizenship_Status = read.csv('Citizenship_Status.csv',header = F)
# clean.Citizenship_Status = (Citizenship_Status[4:55,1:4])
# print(clean.Citizenship_Status)
# Out:
#                      V1          V2          V3    V4
# 4              Location     Citizen Non-Citizen Total
# 5         United States 0.929380153 0.070619525     1
# 6               Alabama 0.980215225 0.019784775     1
# 7                Alaska 0.958656331 0.041343669     1
# 8               Arizona 0.914028181 0.085971819     1
# 9              Arkansas 0.965660806 0.034339194     1
# 10           California 0.860644829 0.139355171     1
# 11             Colorado 0.944232133 0.055767867     1
# 12          Connecticut 0.932070319 0.067958127     1
# 13             Delaware 0.930597264 0.069402736     1
# 14 District of Columbia     0.90448     0.09552     1
# 15              Florida 0.909276597 0.090718153     1
# 16              Georgia 0.943543525  0.05644608     1
# 17               Hawaii 0.920108532 0.079891468     1
# 18                Idaho 0.940755744 0.059180961     1
# 19             Illinois 0.920971017 0.079028983     1
# ...

# %%
# %%R
# #Population distribution by the Federal Poverty Level
# fpl = read.csv('fpl.csv',header = F)
# #print(fpl)
# clean.fpl = (fpl[4:56,1:7])
# print(clean.fpl)
# Out:
#                      V1          V2          V3          V4          V5
# 4              Location  Under 100%   100%-138%   139%-250%   251%-399%
# 5         United States 0.201478101 0.078630695 0.197713325 0.192868024
# 6               Alabama 0.219664393 0.090384003 0.204185511 0.188446561
# 7                Alaska 0.198169573 0.093571545 0.211180094  0.20834034
# 8               Arizona 0.226977565 0.092327974 0.198359862 0.182206024
# 9              Arkansas 0.243154785 0.105162786  0.20906949 0.202721126
# 10           California 0.231239698 0.087922207 0.192270533 0.163812873
# 11             Colorado 0.166283636  0.06469581 0.168288349 0.194474461
# 12          Connecticut 0.147110733 0.059675357 0.155411687 0.178018135
# 13             Delaware 0.187855101 0.084382617 0.190892653 0.202941683
# 14 District of Columbia 0.243237576 0.069484168 0.124236513 0.120915816
# 15              Florida 0.205145787 0.088651604 0.208646023 0.202969499
# ...

# %%
# %%R
# #Median Annual Income
# Median_Annual_Income = read.csv('Median_Annual_Income.csv',header = F)
# #print(Median_Annual_Income)
# clean.Median_Annual_Income = (Median_Annual_Income[4:56,1:2])
# print(clean.Median_Annual_Income)
# Out:
#                      V1                   V2
# 4              Location Median Annual Income
# 5         United States                50443
# 6               Alabama                42245
# 7                Alaska                60566
# 8               Arizona                48319
# 9              Arkansas                39806
# 10           California                56074
# 11             Colorado                59803
# 12          Connecticut                67165
# 13             Delaware                55421
# 14 District of Columbia                56566
# 15              Florida                46136
# 16              Georgia                45642
# 17               Hawaii                59605
# 18                Idaho                48348
# 19             Illinois                52801
# 20              Indiana                46166
# 21                 Iowa                51322
# 22               Kansas                46847
# 23             Kentucky                42331
# ...

# %%
# %%R
# ##Unemployment Rate
#
# unemployment_rate = read.csv('unemployment_rate.csv',header = F)
# #print(unemployment_rate)
# clean.unemployment_rate = (unemployment_rate[4:57,1:3])
# print(clean.unemployment_rate)
# Out:
#                      V1           V2           V3
# 4              Location October 2012 October 2013
# 5         United States        0.079        0.073
# 6               Alabama        0.071        0.065
# 7                Alaska        0.068        0.065
# 8               Arizona        0.081        0.082
# 9              Arkansas        0.072        0.075
# 10           California        0.101        0.087
# 11             Colorado        0.077        0.068
# 12          Connecticut        0.084        0.079
# 13             Delaware        0.071        0.068
# 14 District of Columbia        0.086        0.089
# 15              Florida        0.082        0.067
# 16              Georgia        0.088        0.081
# 17               Hawaii        0.054        0.044
# 18                Idaho        0.066        0.067
# 19             Illinois        0.088        0.089
# 20              Indiana        0.084        0.075
# 21                 Iowa        0.051        0.046
# ...

# %%
# %%R
#
# #Total Population that is Insured
#
# pop_insured = read.csv('Has_Insurance.csv',header = F)
# #print(pop_insured)
# clean.pop_insured = (pop_insured[4:56,1:8])
# print(clean.pop_insured)
# Out:
#                      V1          V2            V3          V4          V5
# 4              Location    Employer Other Private    Medicaid    Medicare
# 5         United States 0.481836572   0.050843092 0.164725054 0.135257376
# 6               Alabama 0.474269324   0.049995813  0.16361695 0.156456746
# 7                Alaska 0.496267585   0.034022394 0.148148148 0.081682458
# 8               Arizona 0.450622444   0.042590707 0.182112511 0.132149751
# 9              Arkansas  0.39978667   0.041392836  0.18951932 0.171730379
# 10           California 0.447709005    0.06003722 0.193663577 0.100804314
# 11             Colorado  0.51849736    0.07322118 0.130840753  0.11752423
# 12          Connecticut 0.579137509   0.049980088 0.148119702 0.135005974
# 13             Delaware  0.50617284   0.035146257 0.178511845 0.168835502
# 14 District of Columbia     0.49408       0.06928     0.25264     0.09712
# 15              Florida 0.410366139   0.054387835 0.138453218 0.170267844
# ...

# %%
# %%R
#
# #Hospital Ownership Type
#
# Hospital_Owners = read.csv('Hospital_Owners.csv',header = F)
# #print(Hospital_Owners)
# clean.Hospital_Owners = (Hospital_Owners[4:56,1:5])
# print(clean.Hospital_Owners)
# Out:
#                      V1                     V2         V3         V4    V5
# 4              Location State/Local Government Non-Profit For-Profit Total
# 5         United States                   21.0       58.4       20.6 100.0
# 6               Alabama                   38.2       23.5       38.2 100.0
# 7                Alaska                   30.4       60.9        8.7 100.0
# 8               Arizona                    5.7       67.1       27.1 100.0
# 9              Arkansas                   13.1       59.5       27.4 100.0
# 10           California                   20.0       58.6       21.4 100.0
# 11             Colorado                   32.9       46.3       20.7 100.0
# 12          Connecticut                    2.9       94.3        2.9 100.0
# 13             Delaware                   <NA>       85.7       14.3 100.0
# 14 District of Columbia                    9.1       63.6       27.3 100.0
# ...

# %%
# %%R
#
# #Federal Funding for Aids prevention
#
# Federal_Funds = read.csv('Federal_Funds.csv',header = F)
# #print(Federal_Funds)
# clean.Federal_Funds = (Federal_Funds[4:64,1:7])
# print(clean.Federal_Funds)
# Out:
#                                V1                   V2        V3        V4
# 4                        Location CDC HIV/AIDS Funding     HOPWA    SAMHSA
# 5                   United States            567813464 298800000 127418359
# 6                         Alabama              5364379   2001172   4616715
# 7                          Alaska              1531605         0         0
# 8                         Arizona              6994996   2498250   1485329
# 9                        Arkansas              2084182    863949         0
# 10                     California             71758702  39343180  21545633
# 11                       Colorado              8115316   2000579   2558579
# 12                    Connecticut              6845004   3228628   1920666
# 13                       Delaware              2045390    843369    495124
# 14           District of Columbia             19053043  13623582   4794266
# ...

# %%
# %%R
#
# #Hiv Testing Rate
#
# Test_Rate = read.csv('Test_Rate.csv',header = F)
# #print(Test_Rate)
# clean.Test_Rate = (Test_Rate[4:58,1:2])
# print(clean.Test_Rate)
# Out:
#                      V1                             V2
# 4              Location HIV Testing Rate - Ever Tested
# 5         United States                           0.37
# 6               Alabama                           0.42
# 7                Alaska                          0.443
# 8               Arizona                          0.341
# 9              Arkansas                          0.311
# 10           California                          0.392
# 11             Colorado                          0.361
# 12          Connecticut                          0.341
# 13             Delaware                          0.428
# 14 District of Columbia                          0.663
# 15              Florida                          0.428
# 16              Georgia                          0.443
# 17               Hawaii                          0.297
# 18                Idaho                          0.286
# 19             Illinois                          0.305
# ...

# %%
# %%R
#
# #Sex Ed Grades 6-8
#
# Sex_Ed_6_8 = read.csv('Sex_Ed_6_8.csv',header = F)
# #print(Sex_Ed_6_8)
# clean.Sex_Ed_6_8 = (Sex_Ed_6_8[4:56,1:3])
# print(clean.Sex_Ed_6_8)
# Out:
#                      V1
# 4              Location
# 5         United States
# 6               Alabama
# 7                Alaska
# 8               Arizona
# 9              Arkansas
# 10           California
# 11             Colorado
# 12          Connecticut
# 13             Delaware
# 14 District of Columbia
# 15              Florida
# 16              Georgia
# 17               Hawaii
# 18                Idaho
# 19             Illinois
# 20              Indiana
# 21                 Iowa
# 22               Kansas
# 23             Kentucky
# 24            Louisiana
# 25                Maine
# 26             Maryland
# 27        Massachusetts
# 28             Michigan
# 29            Minnesota
# 30          Mississippi
# 31             Missouri
# 32              Montana
# 33             Nebraska
# 34               Nevada
# 35        New Hampshire
# 36           New Jersey
# 37           New Mexico
# 38             New York
# 39       North Carolina
# 40         North Dakota
# ...

# %%
# %%R
#
# #Sex Ed Grades 9-12
#
# Sex_Ed_9_12 = read.csv('Sex_Ed_9_12.csv',header = F)
# #print(Sex_Ed_9_12)
# clean.Sex_Ed_9_12 = (Sex_Ed_9_12[4:56,1:3])
# print(clean.Sex_Ed_9_12)
# Out:
#                      V1
# 4              Location
# 5         United States
# 6               Alabama
# 7                Alaska
# 8               Arizona
# 9              Arkansas
# 10           California
# 11             Colorado
# 12          Connecticut
# 13             Delaware
# 14 District of Columbia
# 15              Florida
# 16              Georgia
# 17               Hawaii
# 18                Idaho
# 19             Illinois
# 20              Indiana
# 21                 Iowa
# 22               Kansas
# 23             Kentucky
# 24            Louisiana
# 25                Maine
# 26             Maryland
# 27        Massachusetts
# 28             Michigan
# 29            Minnesota
# 30          Mississippi
# 31             Missouri
# 32              Montana
# 33             Nebraska
# 34               Nevada
# 35        New Hampshire
# 36           New Jersey
# 37           New Mexico
# 38             New York
# 39       North Carolina
# 40         North Dakota
# ...

# %%
# %%R
#
# #Number of Reported Chlamydia Cases
#
# chlamydia_cases = read.csv('chlamydia_cases.csv',header = F)
# #print(chlamydia_cases)
# clean.chlamydia_cases = (chlamydia_cases[4:59,1:2])
# print(clean.chlamydia_cases)
# Out:
#                      V1              V2
# 4              Location Chlamydia Cases
# 5         United States         1412791
# 6               Alabama           29626
# 7                Alaska            5739
# 8               Arizona           29251
# 9              Arkansas           16052
# 10           California          166773
# 11             Colorado           21811
# 12          Connecticut           13649
# 13             Delaware            4508
# 14 District of Columbia            6585
# 15              Florida           76033
# 16              Georgia           54403
# 17               Hawaii            6001
# 18                Idaho            4699
# 19             Illinois           64939
# 20              Indiana           27801
# 21                 Iowa           10705
# 22               Kansas           10598
# 23             Kentucky           16629
# 24            Louisiana           31614
# 25                Maine            3094
# ...

# %%
# %%R
#
# #Number of Reported Gonorrhea Cases
#
# gonorrhea_cases = read.csv('gonorrhea_cases.csv',header = F)
# #print(gonorrhea_cases)
# clean.gonorrhea_cases = (gonorrhea_cases[4:59,1:2])
# print(clean.gonorrhea_cases)
# Out:
#                      V1              V2
# 4              Location Gonorrhea Cases
# 5         United States          321849
# 6               Alabama            9132
# 7                Alaska             984
# 8               Arizona            4564
# 9              Arkansas            4687
# 10           California           27516
# 11             Colorado            2363
# 12          Connecticut            2449
# 13             Delaware             827
# 14 District of Columbia            2569
# 15              Florida           19689
# 16              Georgia           16428
# 17               Hawaii             685
# 18                Idaho             162
# 19             Illinois           17037
# 20              Indiana            6569
# 21                 Iowa            1920
# 22               Kansas            2209
# 23             Kentucky            4521
# 24            Louisiana            9169
# 25                Maine             272
# ...

# %%
# %%R
#
# #Number of Reported syphilis Cases
#
# syphilis_cases = read.csv('syphilis_cases.csv',header = F)
# #print(syphilis_cases)
# clean.syphilis_cases = (syphilis_cases[4:59,1:2])
# print(clean.syphilis_cases)
# Out:
#                      V1             V2
# 4              Location Syphilis Cases
# 5         United States          46042
# 6               Alabama            758
# 7                Alaska             11
# 8               Arizona            906
# 9              Arkansas            464
# 10           California           6782
# 11             Colorado            367
# 12          Connecticut            189
# 13             Delaware            124
# 14 District of Columbia            552
# 15              Florida           4142
# 16              Georgia           1895
# 17               Hawaii             32
# 18                Idaho             42
# 19             Illinois           2426
# 20              Indiana            468
# 21                 Iowa             70
# 22               Kansas             76
# 23             Kentucky            335
# 24            Louisiana           2043
# 25                Maine             24
# 26             Maryland           1278
# ...
